# %% [markdown]
# <a href="https://colab.research.google.com/github/GruAna/VU/blob/master/data_to_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import os
import xml.etree.ElementTree as ET

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp drive/MyDrive/Colab_Notebooks/VU/utils.py .
from utils import *

# %%
from tqdm import tqdm

# %% [markdown]
# Functions

# %%
labels_dir = '/content/drive/MyDrive/Colab_Notebooks/VU/CTW1500/ctw1500_train_labels'
(_, _, xml_files) = next(os.walk(labels_dir))
xml_files.sort()
list_xml_paths = [os.path.join(labels_dir, file) for file in xml_files][:200]

# %%
def read_gt_ctw_train(xml_file, scaling_ratio=1):
    """
    SCUT-CTW1500 dataset (XML - train labels parser)
    Returns ground truth in a tuple - first contains coordinates (8 numbers), second word (string).
    If image was previously scaled, one might need to scale also gt coordinates by given ratio.
    """
    gt = []

    tree = ET.parse(xml_file)
    root = tree.getroot()

    # get values in this order: height, left coordinate, top coordinate, width
    for i, bbox in enumerate(root[0].findall('box')):
        # create list of integers with bounding box values, sort by attribute name
        # in case in different document there is a different order of attributes
        bbox_integer = [int(val) for key, val in sorted(bbox.attrib.items(), key = lambda el: el[0])]
        
        # calculate bottom coordinate of bounding rectangle x+width, y+height
        x_right= int((bbox_integer[1] + bbox_integer[3]) * scaling_ratio)
        y_bottom = int((bbox_integer[2] + bbox_integer[0]) * scaling_ratio)
        x_left = int(bbox_integer[1] * scaling_ratio)
        y_top = int(bbox_integer[2] * scaling_ratio)

        bbox_coords = np.array([[x_left, y_top], [x_right, y_bottom]])

        # get label
        label = root[0][i].find('label').text

        # create list of labels and corresponding boundin boxes
        gt.append((label, bbox_coords))

    return gt

# %%
ground_truth = []

for i, file in tqdm(enumerate(list_xml_paths)):
     ground_truth.append(read_gt_ctw_train(file))
# ground_truth is in the is a list of tuples, where first is the gt word 
# and second is an array of top left and bottom right coordinates
# Out:
# 200it [01:26,  2.30it/s]

# %%
# path to image directory, get full path to all files
imgs_dir = '/content/drive/MyDrive/Colab_Notebooks/VU/CTW1500/train_images'
(_, _, filenames) = next(os.walk(imgs_dir))
filenames.sort()
list_img_paths = [os.path.join(imgs_dir, file) for file in filenames][:200]
n_imgs = len(list_img_paths)

# %%
# load images
images = [(cv.imread(file)) for file in list_img_paths]

# %% [markdown]
# ## Crop

# %%
def image_text_crop(images, filenames, ground_truth, one_file=True, result_folder='./results'):
    """
    Crops and saves images based on bounding box ground truth for each text region.
    Creates text file with corresponding annotation.

    Parameter:
    - images: loaded images
    - filenames: list of image filenames with extension
    - groun_truth: list of gt tuples first text annotation, second np.array of 
    left top and bottom right coodinates, format: ('text', [[tl,tl],[br,br]])
    """

    # test if there are not more gts than images
    # else the for loop will never get to those exceeding image count
    gt_length = len(ground_truth)
    if len(images) > gt_length:
        images = images[:gt_length]

    if not os.path.isdir(result_folder):
        os.mkdir(result_folder)
    
    all_texts = []
    for i, img in tqdm(enumerate(images)):
        name, ext = os.path.splitext(filenames[i])

        # count regions in one image - used for file naming purposes
        region = 1
        
        for text, bbox in ground_truth[i]:
            # select image within coordinates (bbox)
            cropped = img[bbox[0,1]:bbox[1,1], bbox[0,0]:bbox[1,0]]

            # create image file:
            # name in format "original-00region.ext"
            new_name = name + '-' + str(region).zfill(3)
            ext_tif = '.tif'

            cv.imwrite(os.path.join(result_folder, new_name + ext_tif), cropped)
            # create  text annotation file(s)
            if one_file:
                all_texts.append(new_name + ext_tif + '\t' + text)
            else:
                # one file for each image with word
                with open(os.path.join(result_folder, new_name + '.gt.txt'), 'w') as f:
                    f.write(text)
            region += 1
    
    if one_file:
        with open(os.path.join(result_folder, 'gt.txt'), 'w') as f:
            for line in all_texts:
                f.writelines(line+'\n')

# %%
# ! rm -r ../results
image_text_crop(images, filenames[:200], ground_truth, one_file=False)
# Out:
# 200it [00:15, 13.07it/s]

# %%
# ! rm -r ./results

# %% [markdown]
# ## Tesseract

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 3s (1,655 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 155632 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
! tesseract --version
# Out:
# tesseract 4.0.0-beta.1
#  leptonica-1.75.3
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.2) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.3.0
#
#  Found AVX2
#  Found AVX
#  Found SSE

# %%
! sudo apt-get install libicu-dev libpango1.0-dev libcairo2-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libicu-dev is already the newest version (60.2-3ubuntu3.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-freedesktop
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libcairo-script-interpreter2 libfile-stripnondeterminism-perl libmagic-mgc
#   libmagic1 libmail-sendmail-perl libpangoxft-1.0-0 libpixman-1-dev
#   libsigsegv2 libsys-hostname-long-perl libtimedate-perl libtool
#   libxcb-shm0-dev m4 po-debconf
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev libcairo2-doc imagemagick libpango1.0-doc
#   libtool-doc gcj-jdk m4-doc libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-freedesktop
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libmagic-mgc libmagic1 libmail-sendmail-perl libpango1.0-dev
#   libpangoxft-1.0-0 libpixman-1-dev libsigsegv2 libsys-hostname-long-perl
#   libtimedate-perl libtool libxcb-shm0-dev m4 po-debconf
# 0 upgraded, 31 newly installed, 0 to remove and 45 not upgraded.
# Need to get 6,007 kB of archives.
# After this operation, 27.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Fetched 6,007 kB in 3s (1,732 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 31.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 155679 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../20-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../21-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../22-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../23-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../24-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../25-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../26-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../27-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../28-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../29-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../30-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up dh-autoreconf (17) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# Clone repositories for training tesseract.

# %%
% cd /content
# Out:
# /content

# %%
# ! rm -r tesstrain

# %%
! git clone https://github.com/tesseract-ocr/tesstrain
# ! git clone https://github.com/tesseract-ocr/tessdata_best
# Out:
# Cloning into 'tesstrain'...
# remote: Enumerating objects: 819, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 819 (delta 21), reused 25 (delta 11), pack-reused 775
# Receiving objects: 100% (819/819), 13.37 MiB | 15.15 MiB/s, done.
# Resolving deltas: 100% (463/463), done.

# %%
% cd ./tesstrain
# Out:
# /content/tesstrain

# %%
! pwd
# Out:
# /content/tesstrain

# %%
! mkdir data
! mkdir ./data/foo-ground-truth

# %%
! rm -r data
! mkdir data
! mkdir ./data/foo-ground-truth

# %%
! cp ../results/* ./data/foo-ground-truth

# %%
# ! unzip ./ocrd-testset.zip -d ./data/foo-ground-truth

# %%
kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 bc amd64 1.07.1-2 [86.2 kB]
# Fetched 86.2 kB in 1s (86.9 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package bc.
# (Reading database ... 157174 files and directories currently installed.)
# Preparing to unpack .../archives/bc_1.07.1-2_amd64.deb ...
# Unpacking bc (1.07.1-2) ...
# Setting up bc (1.07.1-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
! make training MODEL_NAME=foo MAX_ITERATIONS=600 START_MODEL=eng TESSDATA=/usr/share/tesseract-ocr/4.00/tessdata
# Out:
# Streaming output truncated to the last 5000 lines.
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0092-018.tif" -t "data/foo-ground-truth/0092-018.gt.txt" > "data/foo-ground-truth/0092-018.box"
# + tesseract data/foo-ground-truth/0092-018.tif data/foo-ground-truth/0092-018 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0110-015.tif" -t "data/foo-ground-truth/0110-015.gt.txt" > "data/foo-ground-truth/0110-015.box"
# + tesseract data/foo-ground-truth/0110-015.tif data/foo-ground-truth/0110-015 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0124-023.tif" -t "data/foo-ground-truth/0124-023.gt.txt" > "data/foo-ground-truth/0124-023.box"
# + tesseract data/foo-ground-truth/0124-023.tif data/foo-ground-truth/0124-023 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0079-006.tif" -t "data/foo-ground-truth/0079-006.gt.txt" > "data/foo-ground-truth/0079-006.box"
# + tesseract data/foo-ground-truth/0079-006.tif data/foo-ground-truth/0079-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0009-008.tif" -t "data/foo-ground-truth/0009-008.gt.txt" > "data/foo-ground-truth/0009-008.box"
# + tesseract data/foo-ground-truth/0009-008.tif data/foo-ground-truth/0009-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0086-006.tif" -t "data/foo-ground-truth/0086-006.gt.txt" > "data/foo-ground-truth/0086-006.box"
# + tesseract data/foo-ground-truth/0086-006.tif data/foo-ground-truth/0086-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0091-007.tif" -t "data/foo-ground-truth/0091-007.gt.txt" > "data/foo-ground-truth/0091-007.box"
# + tesseract data/foo-ground-truth/0091-007.tif data/foo-ground-truth/0091-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0036-003.tif" -t "data/foo-ground-truth/0036-003.gt.txt" > "data/foo-ground-truth/0036-003.box"
# + tesseract data/foo-ground-truth/0036-003.tif data/foo-ground-truth/0036-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0179-005.tif" -t "data/foo-ground-truth/0179-005.gt.txt" > "data/foo-ground-truth/0179-005.box"
# + tesseract data/foo-ground-truth/0179-005.tif data/foo-ground-truth/0179-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0048-017.tif" -t "data/foo-ground-truth/0048-017.gt.txt" > "data/foo-ground-truth/0048-017.box"
# + tesseract data/foo-ground-truth/0048-017.tif data/foo-ground-truth/0048-017 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0149-005.tif" -t "data/foo-ground-truth/0149-005.gt.txt" > "data/foo-ground-truth/0149-005.box"
# + tesseract data/foo-ground-truth/0149-005.tif data/foo-ground-truth/0149-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0169-020.tif" -t "data/foo-ground-truth/0169-020.gt.txt" > "data/foo-ground-truth/0169-020.box"
# + tesseract data/foo-ground-truth/0169-020.tif data/foo-ground-truth/0169-020 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0068-004.tif" -t "data/foo-ground-truth/0068-004.gt.txt" > "data/foo-ground-truth/0068-004.box"
# + tesseract data/foo-ground-truth/0068-004.tif data/foo-ground-truth/0068-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0096-016.tif" -t "data/foo-ground-truth/0096-016.gt.txt" > "data/foo-ground-truth/0096-016.box"
# + tesseract data/foo-ground-truth/0096-016.tif data/foo-ground-truth/0096-016 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0146-025.tif" -t "data/foo-ground-truth/0146-025.gt.txt" > "data/foo-ground-truth/0146-025.box"
# + tesseract data/foo-ground-truth/0146-025.tif data/foo-ground-truth/0146-025 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0100-008.tif" -t "data/foo-ground-truth/0100-008.gt.txt" > "data/foo-ground-truth/0100-008.box"
# + tesseract data/foo-ground-truth/0100-008.tif data/foo-ground-truth/0100-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0147-006.tif" -t "data/foo-ground-truth/0147-006.gt.txt" > "data/foo-ground-truth/0147-006.box"
# + tesseract data/foo-ground-truth/0147-006.tif data/foo-ground-truth/0147-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0093-020.tif" -t "data/foo-ground-truth/0093-020.gt.txt" > "data/foo-ground-truth/0093-020.box"
# + tesseract data/foo-ground-truth/0093-020.tif data/foo-ground-truth/0093-020 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0060-003.tif" -t "data/foo-ground-truth/0060-003.gt.txt" > "data/foo-ground-truth/0060-003.box"
# + tesseract data/foo-ground-truth/0060-003.tif data/foo-ground-truth/0060-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0184-008.tif" -t "data/foo-ground-truth/0184-008.gt.txt" > "data/foo-ground-truth/0184-008.box"
# + tesseract data/foo-ground-truth/0184-008.tif data/foo-ground-truth/0184-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0102-005.tif" -t "data/foo-ground-truth/0102-005.gt.txt" > "data/foo-ground-truth/0102-005.box"
# + tesseract data/foo-ground-truth/0102-005.tif data/foo-ground-truth/0102-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0004-010.tif" -t "data/foo-ground-truth/0004-010.gt.txt" > "data/foo-ground-truth/0004-010.box"
# + tesseract data/foo-ground-truth/0004-010.tif data/foo-ground-truth/0004-010 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0164-001.tif" -t "data/foo-ground-truth/0164-001.gt.txt" > "data/foo-ground-truth/0164-001.box"
# + tesseract data/foo-ground-truth/0164-001.tif data/foo-ground-truth/0164-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0126-012.tif" -t "data/foo-ground-truth/0126-012.gt.txt" > "data/foo-ground-truth/0126-012.box"
# + tesseract data/foo-ground-truth/0126-012.tif data/foo-ground-truth/0126-012 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0012-003.tif" -t "data/foo-ground-truth/0012-003.gt.txt" > "data/foo-ground-truth/0012-003.box"
# + tesseract data/foo-ground-truth/0012-003.tif data/foo-ground-truth/0012-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0110-010.tif" -t "data/foo-ground-truth/0110-010.gt.txt" > "data/foo-ground-truth/0110-010.box"
# + tesseract data/foo-ground-truth/0110-010.tif data/foo-ground-truth/0110-010 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0176-016.tif" -t "data/foo-ground-truth/0176-016.gt.txt" > "data/foo-ground-truth/0176-016.box"
# + tesseract data/foo-ground-truth/0176-016.tif data/foo-ground-truth/0176-016 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0185-007.tif" -t "data/foo-ground-truth/0185-007.gt.txt" > "data/foo-ground-truth/0185-007.box"
# + tesseract data/foo-ground-truth/0185-007.tif data/foo-ground-truth/0185-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0059-001.tif" -t "data/foo-ground-truth/0059-001.gt.txt" > "data/foo-ground-truth/0059-001.box"
# + tesseract data/foo-ground-truth/0059-001.tif data/foo-ground-truth/0059-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0128-007.tif" -t "data/foo-ground-truth/0128-007.gt.txt" > "data/foo-ground-truth/0128-007.box"
# + tesseract data/foo-ground-truth/0128-007.tif data/foo-ground-truth/0128-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0033-001.tif" -t "data/foo-ground-truth/0033-001.gt.txt" > "data/foo-ground-truth/0033-001.box"
# + tesseract data/foo-ground-truth/0033-001.tif data/foo-ground-truth/0033-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0050-007.tif" -t "data/foo-ground-truth/0050-007.gt.txt" > "data/foo-ground-truth/0050-007.box"
# + tesseract data/foo-ground-truth/0050-007.tif data/foo-ground-truth/0050-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0056-008.tif" -t "data/foo-ground-truth/0056-008.gt.txt" > "data/foo-ground-truth/0056-008.box"
# + tesseract data/foo-ground-truth/0056-008.tif data/foo-ground-truth/0056-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0153-004.tif" -t "data/foo-ground-truth/0153-004.gt.txt" > "data/foo-ground-truth/0153-004.box"
# + tesseract data/foo-ground-truth/0153-004.tif data/foo-ground-truth/0153-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0137-014.tif" -t "data/foo-ground-truth/0137-014.gt.txt" > "data/foo-ground-truth/0137-014.box"
# + tesseract data/foo-ground-truth/0137-014.tif data/foo-ground-truth/0137-014 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0146-017.tif" -t "data/foo-ground-truth/0146-017.gt.txt" > "data/foo-ground-truth/0146-017.box"
# + tesseract data/foo-ground-truth/0146-017.tif data/foo-ground-truth/0146-017 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0070-014.tif" -t "data/foo-ground-truth/0070-014.gt.txt" > "data/foo-ground-truth/0070-014.box"
# + tesseract data/foo-ground-truth/0070-014.tif data/foo-ground-truth/0070-014 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0035-003.tif" -t "data/foo-ground-truth/0035-003.gt.txt" > "data/foo-ground-truth/0035-003.box"
# + tesseract data/foo-ground-truth/0035-003.tif data/foo-ground-truth/0035-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0124-005.tif" -t "data/foo-ground-truth/0124-005.gt.txt" > "data/foo-ground-truth/0124-005.box"
# + tesseract data/foo-ground-truth/0124-005.tif data/foo-ground-truth/0124-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0169-005.tif" -t "data/foo-ground-truth/0169-005.gt.txt" > "data/foo-ground-truth/0169-005.box"
# + tesseract data/foo-ground-truth/0169-005.tif data/foo-ground-truth/0169-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0197-010.tif" -t "data/foo-ground-truth/0197-010.gt.txt" > "data/foo-ground-truth/0197-010.box"
# + tesseract data/foo-ground-truth/0197-010.tif data/foo-ground-truth/0197-010 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0056-011.tif" -t "data/foo-ground-truth/0056-011.gt.txt" > "data/foo-ground-truth/0056-011.box"
# + tesseract data/foo-ground-truth/0056-011.tif data/foo-ground-truth/0056-011 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0097-009.tif" -t "data/foo-ground-truth/0097-009.gt.txt" > "data/foo-ground-truth/0097-009.box"
# + tesseract data/foo-ground-truth/0097-009.tif data/foo-ground-truth/0097-009 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0139-007.tif" -t "data/foo-ground-truth/0139-007.gt.txt" > "data/foo-ground-truth/0139-007.box"
# + tesseract data/foo-ground-truth/0139-007.tif data/foo-ground-truth/0139-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0151-003.tif" -t "data/foo-ground-truth/0151-003.gt.txt" > "data/foo-ground-truth/0151-003.box"
# + tesseract data/foo-ground-truth/0151-003.tif data/foo-ground-truth/0151-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0044-003.tif" -t "data/foo-ground-truth/0044-003.gt.txt" > "data/foo-ground-truth/0044-003.box"
# + tesseract data/foo-ground-truth/0044-003.tif data/foo-ground-truth/0044-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0093-002.tif" -t "data/foo-ground-truth/0093-002.gt.txt" > "data/foo-ground-truth/0093-002.box"
# + tesseract data/foo-ground-truth/0093-002.tif data/foo-ground-truth/0093-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0096-001.tif" -t "data/foo-ground-truth/0096-001.gt.txt" > "data/foo-ground-truth/0096-001.box"
# + tesseract data/foo-ground-truth/0096-001.tif data/foo-ground-truth/0096-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0021-005.tif" -t "data/foo-ground-truth/0021-005.gt.txt" > "data/foo-ground-truth/0021-005.box"
# + tesseract data/foo-ground-truth/0021-005.tif data/foo-ground-truth/0021-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0185-002.tif" -t "data/foo-ground-truth/0185-002.gt.txt" > "data/foo-ground-truth/0185-002.box"
# + tesseract data/foo-ground-truth/0185-002.tif data/foo-ground-truth/0185-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0127-014.tif" -t "data/foo-ground-truth/0127-014.gt.txt" > "data/foo-ground-truth/0127-014.box"
# + tesseract data/foo-ground-truth/0127-014.tif data/foo-ground-truth/0127-014 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0145-007.tif" -t "data/foo-ground-truth/0145-007.gt.txt" > "data/foo-ground-truth/0145-007.box"
# + tesseract data/foo-ground-truth/0145-007.tif data/foo-ground-truth/0145-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0105-003.tif" -t "data/foo-ground-truth/0105-003.gt.txt" > "data/foo-ground-truth/0105-003.box"
# + tesseract data/foo-ground-truth/0105-003.tif data/foo-ground-truth/0105-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0111-002.tif" -t "data/foo-ground-truth/0111-002.gt.txt" > "data/foo-ground-truth/0111-002.box"
# + tesseract data/foo-ground-truth/0111-002.tif data/foo-ground-truth/0111-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0199-001.tif" -t "data/foo-ground-truth/0199-001.gt.txt" > "data/foo-ground-truth/0199-001.box"
# + tesseract data/foo-ground-truth/0199-001.tif data/foo-ground-truth/0199-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0087-004.tif" -t "data/foo-ground-truth/0087-004.gt.txt" > "data/foo-ground-truth/0087-004.box"
# + tesseract data/foo-ground-truth/0087-004.tif data/foo-ground-truth/0087-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0135-014.tif" -t "data/foo-ground-truth/0135-014.gt.txt" > "data/foo-ground-truth/0135-014.box"
# + tesseract data/foo-ground-truth/0135-014.tif data/foo-ground-truth/0135-014 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0106-004.tif" -t "data/foo-ground-truth/0106-004.gt.txt" > "data/foo-ground-truth/0106-004.box"
# + tesseract data/foo-ground-truth/0106-004.tif data/foo-ground-truth/0106-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0139-002.tif" -t "data/foo-ground-truth/0139-002.gt.txt" > "data/foo-ground-truth/0139-002.box"
# + tesseract data/foo-ground-truth/0139-002.tif data/foo-ground-truth/0139-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0008-012.tif" -t "data/foo-ground-truth/0008-012.gt.txt" > "data/foo-ground-truth/0008-012.box"
# + tesseract data/foo-ground-truth/0008-012.tif data/foo-ground-truth/0008-012 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0063-002.tif" -t "data/foo-ground-truth/0063-002.gt.txt" > "data/foo-ground-truth/0063-002.box"
# + tesseract data/foo-ground-truth/0063-002.tif data/foo-ground-truth/0063-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0172-003.tif" -t "data/foo-ground-truth/0172-003.gt.txt" > "data/foo-ground-truth/0172-003.box"
# + tesseract data/foo-ground-truth/0172-003.tif data/foo-ground-truth/0172-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0033-006.tif" -t "data/foo-ground-truth/0033-006.gt.txt" > "data/foo-ground-truth/0033-006.box"
# + tesseract data/foo-ground-truth/0033-006.tif data/foo-ground-truth/0033-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0173-005.tif" -t "data/foo-ground-truth/0173-005.gt.txt" > "data/foo-ground-truth/0173-005.box"
# + tesseract data/foo-ground-truth/0173-005.tif data/foo-ground-truth/0173-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0171-002.tif" -t "data/foo-ground-truth/0171-002.gt.txt" > "data/foo-ground-truth/0171-002.box"
# + tesseract data/foo-ground-truth/0171-002.tif data/foo-ground-truth/0171-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0096-021.tif" -t "data/foo-ground-truth/0096-021.gt.txt" > "data/foo-ground-truth/0096-021.box"
# + tesseract data/foo-ground-truth/0096-021.tif data/foo-ground-truth/0096-021 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0095-017.tif" -t "data/foo-ground-truth/0095-017.gt.txt" > "data/foo-ground-truth/0095-017.box"
# + tesseract data/foo-ground-truth/0095-017.tif data/foo-ground-truth/0095-017 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0115-001.tif" -t "data/foo-ground-truth/0115-001.gt.txt" > "data/foo-ground-truth/0115-001.box"
# + tesseract data/foo-ground-truth/0115-001.tif data/foo-ground-truth/0115-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0179-004.tif" -t "data/foo-ground-truth/0179-004.gt.txt" > "data/foo-ground-truth/0179-004.box"
# + tesseract data/foo-ground-truth/0179-004.tif data/foo-ground-truth/0179-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0040-008.tif" -t "data/foo-ground-truth/0040-008.gt.txt" > "data/foo-ground-truth/0040-008.box"
# + tesseract data/foo-ground-truth/0040-008.tif data/foo-ground-truth/0040-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0127-001.tif" -t "data/foo-ground-truth/0127-001.gt.txt" > "data/foo-ground-truth/0127-001.box"
# + tesseract data/foo-ground-truth/0127-001.tif data/foo-ground-truth/0127-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0171-010.tif" -t "data/foo-ground-truth/0171-010.gt.txt" > "data/foo-ground-truth/0171-010.box"
# + tesseract data/foo-ground-truth/0171-010.tif data/foo-ground-truth/0171-010 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0095-015.tif" -t "data/foo-ground-truth/0095-015.gt.txt" > "data/foo-ground-truth/0095-015.box"
# + tesseract data/foo-ground-truth/0095-015.tif data/foo-ground-truth/0095-015 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0161-007.tif" -t "data/foo-ground-truth/0161-007.gt.txt" > "data/foo-ground-truth/0161-007.box"
# + tesseract data/foo-ground-truth/0161-007.tif data/foo-ground-truth/0161-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0052-009.tif" -t "data/foo-ground-truth/0052-009.gt.txt" > "data/foo-ground-truth/0052-009.box"
# + tesseract data/foo-ground-truth/0052-009.tif data/foo-ground-truth/0052-009 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0163-003.tif" -t "data/foo-ground-truth/0163-003.gt.txt" > "data/foo-ground-truth/0163-003.box"
# + tesseract data/foo-ground-truth/0163-003.tif data/foo-ground-truth/0163-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0124-032.tif" -t "data/foo-ground-truth/0124-032.gt.txt" > "data/foo-ground-truth/0124-032.box"
# + tesseract data/foo-ground-truth/0124-032.tif data/foo-ground-truth/0124-032 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0164-011.tif" -t "data/foo-ground-truth/0164-011.gt.txt" > "data/foo-ground-truth/0164-011.box"
# + tesseract data/foo-ground-truth/0164-011.tif data/foo-ground-truth/0164-011 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0103-003.tif" -t "data/foo-ground-truth/0103-003.gt.txt" > "data/foo-ground-truth/0103-003.box"
# + tesseract data/foo-ground-truth/0103-003.tif data/foo-ground-truth/0103-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0035-007.tif" -t "data/foo-ground-truth/0035-007.gt.txt" > "data/foo-ground-truth/0035-007.box"
# + tesseract data/foo-ground-truth/0035-007.tif data/foo-ground-truth/0035-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0137-031.tif" -t "data/foo-ground-truth/0137-031.gt.txt" > "data/foo-ground-truth/0137-031.box"
# + tesseract data/foo-ground-truth/0137-031.tif data/foo-ground-truth/0137-031 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0040-018.tif" -t "data/foo-ground-truth/0040-018.gt.txt" > "data/foo-ground-truth/0040-018.box"
# + tesseract data/foo-ground-truth/0040-018.tif data/foo-ground-truth/0040-018 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0112-011.tif" -t "data/foo-ground-truth/0112-011.gt.txt" > "data/foo-ground-truth/0112-011.box"
# + tesseract data/foo-ground-truth/0112-011.tif data/foo-ground-truth/0112-011 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0184-026.tif" -t "data/foo-ground-truth/0184-026.gt.txt" > "data/foo-ground-truth/0184-026.box"
# + tesseract data/foo-ground-truth/0184-026.tif data/foo-ground-truth/0184-026 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0020-013.tif" -t "data/foo-ground-truth/0020-013.gt.txt" > "data/foo-ground-truth/0020-013.box"
# + tesseract data/foo-ground-truth/0020-013.tif data/foo-ground-truth/0020-013 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0179-024.tif" -t "data/foo-ground-truth/0179-024.gt.txt" > "data/foo-ground-truth/0179-024.box"
# + tesseract data/foo-ground-truth/0179-024.tif data/foo-ground-truth/0179-024 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0024-019.tif" -t "data/foo-ground-truth/0024-019.gt.txt" > "data/foo-ground-truth/0024-019.box"
# + tesseract data/foo-ground-truth/0024-019.tif data/foo-ground-truth/0024-019 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0052-004.tif" -t "data/foo-ground-truth/0052-004.gt.txt" > "data/foo-ground-truth/0052-004.box"
# + tesseract data/foo-ground-truth/0052-004.tif data/foo-ground-truth/0052-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0104-012.tif" -t "data/foo-ground-truth/0104-012.gt.txt" > "data/foo-ground-truth/0104-012.box"
# + tesseract data/foo-ground-truth/0104-012.tif data/foo-ground-truth/0104-012 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0086-008.tif" -t "data/foo-ground-truth/0086-008.gt.txt" > "data/foo-ground-truth/0086-008.box"
# + tesseract data/foo-ground-truth/0086-008.tif data/foo-ground-truth/0086-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0029-005.tif" -t "data/foo-ground-truth/0029-005.gt.txt" > "data/foo-ground-truth/0029-005.box"
# + tesseract data/foo-ground-truth/0029-005.tif data/foo-ground-truth/0029-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0014-002.tif" -t "data/foo-ground-truth/0014-002.gt.txt" > "data/foo-ground-truth/0014-002.box"
# + tesseract data/foo-ground-truth/0014-002.tif data/foo-ground-truth/0014-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0098-006.tif" -t "data/foo-ground-truth/0098-006.gt.txt" > "data/foo-ground-truth/0098-006.box"
# + tesseract data/foo-ground-truth/0098-006.tif data/foo-ground-truth/0098-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0143-011.tif" -t "data/foo-ground-truth/0143-011.gt.txt" > "data/foo-ground-truth/0143-011.box"
# + tesseract data/foo-ground-truth/0143-011.tif data/foo-ground-truth/0143-011 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0171-012.tif" -t "data/foo-ground-truth/0171-012.gt.txt" > "data/foo-ground-truth/0171-012.box"
# + tesseract data/foo-ground-truth/0171-012.tif data/foo-ground-truth/0171-012 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0022-012.tif" -t "data/foo-ground-truth/0022-012.gt.txt" > "data/foo-ground-truth/0022-012.box"
# + tesseract data/foo-ground-truth/0022-012.tif data/foo-ground-truth/0022-012 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0043-002.tif" -t "data/foo-ground-truth/0043-002.gt.txt" > "data/foo-ground-truth/0043-002.box"
# + tesseract data/foo-ground-truth/0043-002.tif data/foo-ground-truth/0043-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0140-005.tif" -t "data/foo-ground-truth/0140-005.gt.txt" > "data/foo-ground-truth/0140-005.box"
# + tesseract data/foo-ground-truth/0140-005.tif data/foo-ground-truth/0140-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0149-004.tif" -t "data/foo-ground-truth/0149-004.gt.txt" > "data/foo-ground-truth/0149-004.box"
# + tesseract data/foo-ground-truth/0149-004.tif data/foo-ground-truth/0149-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0033-003.tif" -t "data/foo-ground-truth/0033-003.gt.txt" > "data/foo-ground-truth/0033-003.box"
# + tesseract data/foo-ground-truth/0033-003.tif data/foo-ground-truth/0033-003 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0177-025.tif" -t "data/foo-ground-truth/0177-025.gt.txt" > "data/foo-ground-truth/0177-025.box"
# + tesseract data/foo-ground-truth/0177-025.tif data/foo-ground-truth/0177-025 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0089-008.tif" -t "data/foo-ground-truth/0089-008.gt.txt" > "data/foo-ground-truth/0089-008.box"
# + tesseract data/foo-ground-truth/0089-008.tif data/foo-ground-truth/0089-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0002-002.tif" -t "data/foo-ground-truth/0002-002.gt.txt" > "data/foo-ground-truth/0002-002.box"
# + tesseract data/foo-ground-truth/0002-002.tif data/foo-ground-truth/0002-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0184-024.tif" -t "data/foo-ground-truth/0184-024.gt.txt" > "data/foo-ground-truth/0184-024.box"
# + tesseract data/foo-ground-truth/0184-024.tif data/foo-ground-truth/0184-024 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0049-006.tif" -t "data/foo-ground-truth/0049-006.gt.txt" > "data/foo-ground-truth/0049-006.box"
# + tesseract data/foo-ground-truth/0049-006.tif data/foo-ground-truth/0049-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0178-002.tif" -t "data/foo-ground-truth/0178-002.gt.txt" > "data/foo-ground-truth/0178-002.box"
# + tesseract data/foo-ground-truth/0178-002.tif data/foo-ground-truth/0178-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0177-002.tif" -t "data/foo-ground-truth/0177-002.gt.txt" > "data/foo-ground-truth/0177-002.box"
# + tesseract data/foo-ground-truth/0177-002.tif data/foo-ground-truth/0177-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0020-009.tif" -t "data/foo-ground-truth/0020-009.gt.txt" > "data/foo-ground-truth/0020-009.box"
# + tesseract data/foo-ground-truth/0020-009.tif data/foo-ground-truth/0020-009 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0078-004.tif" -t "data/foo-ground-truth/0078-004.gt.txt" > "data/foo-ground-truth/0078-004.box"
# + tesseract data/foo-ground-truth/0078-004.tif data/foo-ground-truth/0078-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0143-002.tif" -t "data/foo-ground-truth/0143-002.gt.txt" > "data/foo-ground-truth/0143-002.box"
# + tesseract data/foo-ground-truth/0143-002.tif data/foo-ground-truth/0143-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0030-002.tif" -t "data/foo-ground-truth/0030-002.gt.txt" > "data/foo-ground-truth/0030-002.box"
# + tesseract data/foo-ground-truth/0030-002.tif data/foo-ground-truth/0030-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0070-017.tif" -t "data/foo-ground-truth/0070-017.gt.txt" > "data/foo-ground-truth/0070-017.box"
# + tesseract data/foo-ground-truth/0070-017.tif data/foo-ground-truth/0070-017 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0163-002.tif" -t "data/foo-ground-truth/0163-002.gt.txt" > "data/foo-ground-truth/0163-002.box"
# + tesseract data/foo-ground-truth/0163-002.tif data/foo-ground-truth/0163-002 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0184-007.tif" -t "data/foo-ground-truth/0184-007.gt.txt" > "data/foo-ground-truth/0184-007.box"
# + tesseract data/foo-ground-truth/0184-007.tif data/foo-ground-truth/0184-007 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0092-026.tif" -t "data/foo-ground-truth/0092-026.gt.txt" > "data/foo-ground-truth/0092-026.box"
# + tesseract data/foo-ground-truth/0092-026.tif data/foo-ground-truth/0092-026 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0108-005.tif" -t "data/foo-ground-truth/0108-005.gt.txt" > "data/foo-ground-truth/0108-005.box"
# + tesseract data/foo-ground-truth/0108-005.tif data/foo-ground-truth/0108-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0137-052.tif" -t "data/foo-ground-truth/0137-052.gt.txt" > "data/foo-ground-truth/0137-052.box"
# + tesseract data/foo-ground-truth/0137-052.tif data/foo-ground-truth/0137-052 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0070-020.tif" -t "data/foo-ground-truth/0070-020.gt.txt" > "data/foo-ground-truth/0070-020.box"
# + tesseract data/foo-ground-truth/0070-020.tif data/foo-ground-truth/0070-020 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0124-019.tif" -t "data/foo-ground-truth/0124-019.gt.txt" > "data/foo-ground-truth/0124-019.box"
# + tesseract data/foo-ground-truth/0124-019.tif data/foo-ground-truth/0124-019 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0170-001.tif" -t "data/foo-ground-truth/0170-001.gt.txt" > "data/foo-ground-truth/0170-001.box"
# + tesseract data/foo-ground-truth/0170-001.tif data/foo-ground-truth/0170-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0173-001.tif" -t "data/foo-ground-truth/0173-001.gt.txt" > "data/foo-ground-truth/0173-001.box"
# + tesseract data/foo-ground-truth/0173-001.tif data/foo-ground-truth/0173-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# ...
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0049-008.tif" -t "data/foo-ground-truth/0049-008.gt.txt" > "data/foo-ground-truth/0049-008.box"
# + tesseract data/foo-ground-truth/0049-008.tif data/foo-ground-truth/0049-008 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0022-006.tif" -t "data/foo-ground-truth/0022-006.gt.txt" > "data/foo-ground-truth/0022-006.box"
# + tesseract data/foo-ground-truth/0022-006.tif data/foo-ground-truth/0022-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0156-009.tif" -t "data/foo-ground-truth/0156-009.gt.txt" > "data/foo-ground-truth/0156-009.box"
# + tesseract data/foo-ground-truth/0156-009.tif data/foo-ground-truth/0156-009 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0100-004.tif" -t "data/foo-ground-truth/0100-004.gt.txt" > "data/foo-ground-truth/0100-004.box"
# + tesseract data/foo-ground-truth/0100-004.tif data/foo-ground-truth/0100-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0135-023.tif" -t "data/foo-ground-truth/0135-023.gt.txt" > "data/foo-ground-truth/0135-023.box"
# + tesseract data/foo-ground-truth/0135-023.tif data/foo-ground-truth/0135-023 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0138-001.tif" -t "data/foo-ground-truth/0138-001.gt.txt" > "data/foo-ground-truth/0138-001.box"
# + tesseract data/foo-ground-truth/0138-001.tif data/foo-ground-truth/0138-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0184-006.tif" -t "data/foo-ground-truth/0184-006.gt.txt" > "data/foo-ground-truth/0184-006.box"
# + tesseract data/foo-ground-truth/0184-006.tif data/foo-ground-truth/0184-006 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0082-005.tif" -t "data/foo-ground-truth/0082-005.gt.txt" > "data/foo-ground-truth/0082-005.box"
# + tesseract data/foo-ground-truth/0082-005.tif data/foo-ground-truth/0082-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0122-001.tif" -t "data/foo-ground-truth/0122-001.gt.txt" > "data/foo-ground-truth/0122-001.box"
# + tesseract data/foo-ground-truth/0122-001.tif data/foo-ground-truth/0122-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0018-005.tif" -t "data/foo-ground-truth/0018-005.gt.txt" > "data/foo-ground-truth/0018-005.box"
# + tesseract data/foo-ground-truth/0018-005.tif data/foo-ground-truth/0018-005 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0144-020.tif" -t "data/foo-ground-truth/0144-020.gt.txt" > "data/foo-ground-truth/0144-020.box"
# + tesseract data/foo-ground-truth/0144-020.tif data/foo-ground-truth/0144-020 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0086-019.tif" -t "data/foo-ground-truth/0086-019.gt.txt" > "data/foo-ground-truth/0086-019.box"
# + tesseract data/foo-ground-truth/0086-019.tif data/foo-ground-truth/0086-019 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0079-004.tif" -t "data/foo-ground-truth/0079-004.gt.txt" > "data/foo-ground-truth/0079-004.box"
# + tesseract data/foo-ground-truth/0079-004.tif data/foo-ground-truth/0079-004 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0080-001.tif" -t "data/foo-ground-truth/0080-001.gt.txt" > "data/foo-ground-truth/0080-001.box"
# + tesseract data/foo-ground-truth/0080-001.tif data/foo-ground-truth/0080-001 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# PYTHONIOENCODING=utf-8 python3 generate_line_box.py -i "data/foo-ground-truth/0137-022.tif" -t "data/foo-ground-truth/0137-022.gt.txt" > "data/foo-ground-truth/0137-022.box"
# + tesseract data/foo-ground-truth/0137-022.tif data/foo-ground-truth/0137-022 --psm 13 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# find -L data/foo-ground-truth -name '*.lstmf' | python3 shuffle.py 0 > "data/foo/all-lstmf"
# + head -n 1795 data/foo/all-lstmf
# + tail -n 200 data/foo/all-lstmf
# wget -Odata/radical-stroke.txt 'https://github.com/tesseract-ocr/langdata_lstm/raw/main/radical-stroke.txt'
# --2022-06-06 10:00:28--  https://github.com/tesseract-ocr/langdata_lstm/raw/main/radical-stroke.txt
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tesseract-ocr/langdata_lstm/main/radical-stroke.txt [following]
# --2022-06-06 10:00:28--  https://raw.githubusercontent.com/tesseract-ocr/langdata_lstm/main/radical-stroke.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330874 (323K) [text/plain]
# Saving to: 'data/radical-stroke.txt'
#
# data/radical-stroke 100%[===================>] 323.12K  --.-KB/s    in 0.05s
#
# 2022-06-06 10:00:29 (6.62 MB/s) - 'data/radical-stroke.txt' saved [330874/330874]
#
# combine_lang_model \
#   --input_unicharset data/foo/unicharset \
#   --script_dir data \
#   --numbers data/foo/foo.numbers \
#   --puncs data/foo/foo.punc \
#   --words data/foo/foo.wordlist \
#   --output_dir data \
#    \
#   --lang foo
# Failed to read data from: data/foo/foo.wordlist
# Failed to read data from: data/foo/foo.punc
# Failed to read data from: data/foo/foo.numbers
# Loaded unicharset of size 129 from file data/foo/unicharset
# Setting unichar properties
# Other case É of é is not in unicharset
# Setting script properties
# Failed to load script unicharset from:data/Latin.unicharset
# Failed to load script unicharset from:data/Han.unicharset
# Warning: properties incomplete for index 3 = C
# Warning: properties incomplete for index 4 = H
# Warning: properties incomplete for index 5 = E
# Warning: properties incomplete for index 6 = S
# Warning: properties incomplete for index 7 = -
# Warning: properties incomplete for index 8 = R
# Warning: properties incomplete for index 9 = I
# Warning: properties incomplete for index 10 = K
# Warning: properties incomplete for index 11 = N
# Warning: properties incomplete for index 12 = G
# Warning: properties incomplete for index 13 = B
# Warning: properties incomplete for index 14 = 8
# Warning: properties incomplete for index 15 = 5
# Warning: properties incomplete for index 16 = F
# Warning: properties incomplete for index 17 = ,
# Warning: properties incomplete for index 18 = (
# Warning: properties incomplete for index 19 = /
# Warning: properties incomplete for index 20 = L
# Warning: properties incomplete for index 21 = T
# Warning: properties incomplete for index 22 = )
# Warning: properties incomplete for index 23 = O
# Warning: properties incomplete for index 24 = Y
# Warning: properties incomplete for index 25 = .
# Warning: properties incomplete for index 26 = D
# Warning: properties incomplete for index 27 = A
# Warning: properties incomplete for index 28 = M
# Warning: properties incomplete for index 29 = U
# Warning: properties incomplete for index 30 = P
# Warning: properties incomplete for index 31 = [
# Warning: properties incomplete for index 32 = ]
# Warning: properties incomplete for index 33 = 9
# Warning: properties incomplete for index 34 = 7
# Warning: properties incomplete for index 35 = 0
# Warning: properties incomplete for index 36 = 1
# Warning: properties incomplete for index 37 = 4
# Warning: properties incomplete for index 38 = 2
# Warning: properties incomplete for index 39 = W
# Warning: properties incomplete for index 40 = 3
# Warning: properties incomplete for index 41 = <
# Warning: properties incomplete for index 42 = >
# Warning: properties incomplete for index 43 = "
# Warning: properties incomplete for index 44 = V
# Warning: properties incomplete for index 45 = X
# Warning: properties incomplete for index 46 = '
# Warning: properties incomplete for index 47 = ~
# Warning: properties incomplete for index 48 = !
# Warning: properties incomplete for index 49 = J
# Warning: properties incomplete for index 50 = Q
# Warning: properties incomplete for index 51 = Z
# Warning: properties incomplete for index 52 = +
# Warning: properties incomplete for index 53 = @
# Warning: properties incomplete for index 54 = &
# Warning: properties incomplete for index 55 = ’
# Warning: properties incomplete for index 56 = =
# Warning: properties incomplete for index 57 = _
# Warning: properties incomplete for index 58 = €
# Warning: properties incomplete for index 59 = ™
# Warning: properties incomplete for index 60 = “
# Warning: properties incomplete for index 61 = |
# Warning: properties incomplete for index 62 = ?
# Warning: properties incomplete for index 63 = :
# Warning: properties incomplete for index 64 = 6
# Warning: properties incomplete for index 65 = {
# Warning: properties incomplete for index 66 = }
# Warning: properties incomplete for index 67 = $
# Warning: properties incomplete for index 68 = ;
# Warning: properties incomplete for index 69 = \
# Warning: properties incomplete for index 70 = —
# Warning: properties incomplete for index 71 = ”
# Warning: properties incomplete for index 72 = *
# Warning: properties incomplete for index 73 = #
# Warning: properties incomplete for index 74 = »
# Warning: properties incomplete for index 75 = ®
# Warning: properties incomplete for index 76 = %
# Warning: properties incomplete for index 77 = £
# Warning: properties incomplete for index 78 = «
# Warning: properties incomplete for index 79 = °
# Warning: properties incomplete for index 80 = ©
# Warning: properties incomplete for index 81 = §
# Warning: properties incomplete for index 82 = ¥
# Warning: properties incomplete for index 83 = ¢
# Warning: properties incomplete for index 84 = ‘
# Warning: properties incomplete for index 85 = i
# Warning: properties incomplete for index 86 = n
# Warning: properties incomplete for index 87 = c
# Warning: properties incomplete for index 88 = u
# Warning: properties incomplete for index 89 = l
# Warning: properties incomplete for index 90 = a
# Warning: properties incomplete for index 91 = t
# Warning: properties incomplete for index 92 = e
# Warning: properties incomplete for index 93 = m
# Warning: properties incomplete for index 94 = o
# Warning: properties incomplete for index 95 = s
# Warning: properties incomplete for index 96 = g
# Warning: properties incomplete for index 97 = h
# Warning: properties incomplete for index 98 = b
# Warning: properties incomplete for index 99 = z
# Warning: properties incomplete for index 100 = v
# Warning: properties incomplete for index 101 = q
# Warning: properties incomplete for index 102 = f
# Warning: properties incomplete for index 103 = r
# Warning: properties incomplete for index 104 = w
# Warning: properties incomplete for index 105 = p
# Warning: properties incomplete for index 106 = d
# Warning: properties incomplete for index 107 = k
# Warning: properties incomplete for index 108 = x
# Warning: properties incomplete for index 109 = y
# Warning: properties incomplete for index 110 = j
# Warning: properties incomplete for index 111 = é
# Warning: properties incomplete for index 112 = ·
# Warning: properties incomplete for index 113 = 新
# Warning: properties incomplete for index 114 = 龙
# Warning: properties incomplete for index 115 = 、
# Warning: properties incomplete for index 116 = 泰
# Warning: properties incomplete for index 117 = 林
# Warning: properties incomplete for index 118 = ，
# Warning: properties incomplete for index 119 = 两
# Warning: properties incomplete for index 120 = 店
# Warning: properties incomplete for index 121 = 同
# Warning: properties incomplete for index 122 = 庆
# Warning: properties incomplete for index 123 = 周
# Warning: properties incomplete for index 124 = 年
# Warning: properties incomplete for index 125 = →
# Warning: properties incomplete for index 126 = ←
# Warning: properties incomplete for index 127 = 梦
# Warning: properties incomplete for index 128 = 幻
# Config file is optional, continuing...
# Failed to read data from: data/foo/foo.config
# Null char=2
# lstmtraining \
#   --debug_interval 0 \
#   --traineddata data/foo/foo.traineddata \
#   --old_traineddata /usr/share/tesseract-ocr/4.00/tessdata/eng.traineddata \
#   --continue_from data/eng/foo.lstm \
#   --learning_rate 0.0001 \
#   --model_output data/foo/checkpoints/foo \
#   --train_listfile data/foo/list.train \
#   --eval_listfile data/foo/list.eval \
#   --max_iterations 600 \
#   --target_error_rate 0.01
# Loaded file data/eng/foo.lstm, unpacking...
# Warning: LSTMTrainer deserialized an LSTMRecognizer!
# Code range changed from 111 to 145!
# Num (Extended) outputs,weights in Series:
#   1,36,0,1:1, 0
# Num (Extended) outputs,weights in Series:
#   C3,3:9, 0
#   Ft16:16, 160
# Total weights = 160
#   [C3,3Ft16]:16, 160
#   Mp3,3:16, 0
#   Lfys48:48, 12480
#   Lfx96:96, 55680
#   Lrx96:96, 74112
#   Lfx192:192, 221952
#   Fc145:145, 0
# Total weights = 364384
# Previous null char=110 mapped to 144
# Continuing from data/eng/foo.lstm
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0006-002.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0179-013.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0123-007.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0041-003.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0114-018.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0007-011.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0195-005.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0177-026.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0108-004.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0144-025.lstmf
# Loaded 1/1 pages (1-1) of document data/foo-ground-truth/0121-004.lstmf
# !int_mode_:Error:Assert failed:in file weightmatrix.cpp, line 244
# !int_mode_:Error:Assert failed:in file weightmatrix.cpp, line 244
# Makefile:277: recipe for target 'data/foo/checkpoints/foo_checkpoint' failed
# make: *** [data/foo/checkpoints/foo_checkpoint] Segmentation fault (core dumped)

# %% [markdown]
# Copy new model to /usr/share/tesseract-ocr/4.00/tessdata

# %%
! cp /content/tesstrain/data/foo.traineddata /usr/share/tesseract-ocr/4.00/tessdata

# %%
! ls /usr/share/tesseract-ocr/4.00/tessdata
# Out:
# configs		 foo.traineddata  pdf.ttf
# eng.traineddata  osd.traineddata  tessconfigs

# %%
! tesseract -l foo /content/drive/MyDrive/Colab_Notebooks/VU/CTW1500/train_images/ -
# Out:
# Failed to load any lstm-specific dictionaries for lang foo!!
# Error in findFileFormatStream: failed to read first 12 bytes of file
# terminate called after throwing an instance of 'std::__ios_failure'
#   what():  basic_filebuf::underflow error reading the file: iostream error
